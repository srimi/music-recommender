# %%
#importing all required packages

import numpy as np 
import pandas as pd
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing

# %%
#Load data

df_train = pd.read_csv("train.csv")
df_songs = pd.read_csv("songs.csv")

# %%
df_train.head()
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
#
#                                         song_id source_system_tab  \
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=           explore
# 1  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=        my library
# 2  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=        my library
# 3  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=        my library
# 4  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=           explore
#
#     source_screen_name      source_type  target
# 0              Explore  online-playlist       1
# 1  Local playlist more   local-playlist       1
# 2  Local playlist more   local-playlist       1
# 3  Local playlist more   local-playlist       1
# 4              Explore  online-playlist       1

# %%
df_songs.head()
# Out:
#                                         song_id  song_length genre_ids  \
# 0  CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=       247640       465
# 1  o0kFgae9QtnYgRkVPqLJwa05zIhRlUjfF7O1tDw0ZDU=       197328       444
# 2  DwVvVurfpuz+XPuFvucclVQEyPqcpUkHR0ne1RQzPs0=       231781       465
# 3  dKMBWoZyScdxSkihKG+Vf47nc18N9q4m58+b4e7dSSE=       273554       465
# 4  W3bqWd3T+VeHFzHAUfARgW9AvVRaF4N5Yzm4Mr6Eo/o=       140329       726
#
#         artist_name                            composer     lyricist  language
# 0  張信哲 (Jeff Chang)                                  董貞          何啟弘       3.0
# 1         BLACKPINK  TEDDY|  FUTURE BOUNCE|  Bekuh BOOM        TEDDY      31.0
# 2      SUPER JUNIOR                                 NaN          NaN      31.0
# 3             S.H.E                                 湯小康          徐世珍       3.0
# 4              貴族精選                         Traditional  Traditional      52.0

# %%
#Merge training data and songs data 
df_train = pd.merge(df_train, df_songs, how='inner', on=['song_id'])
df_train.shape[0]
# Out:
# 7377304

# %%
#identifing the number of languages
a = df_train.language.unique()
print(a)
df_train.language.value_counts()
# Out:
# [ 52.  -1.  31.   3.  17.  10.  24.  59.  45.  38.  nan]
#  3.0     4044643
#  52.0    1864789
#  31.0     656623
# -1.0      308752
#  17.0     245136
#  10.0     171904
#  24.0      78621
#  59.0       4193
#  45.0       2397
#  38.0        210
# Name: language, dtype: int64

# %%
#filter songs in language = 3
df_train = df_train.loc[df_train['language'] == -1.0]

# %%
#Remove data without artist name
df_train = df_train.loc[df_train['artist_name'] != 'Various Artists']
df_train.shape[0]
# Out:
# 300932

# %%
#REMOVING NULL VALUES as they hinder the training
df_train = df_train.dropna(how='any')

# %%
df_train.shape[0]
# Out:
# 28770

# %%
#create a new entry for songs with multiple genre_ids - good training 

(df_train.set_index(df_train.columns.drop('genre_ids',1).tolist()).genre_ids.str.split('|', expand=True).stack().reset_index().rename(columns={0:'genre_ids'}).loc[:, df_train.columns])
(df_train.set_index(df_train.columns.drop('composer',1).tolist()).composer.str.split('|', expand=True).stack().reset_index().rename(columns={0:'composer'}).loc[:, df_train.columns])
(df_train.set_index(df_train.columns.drop('lyricist',1).tolist()).lyricist.str.split('|', expand=True).stack().reset_index().rename(columns={0:'lyricist'}).loc[:, df_train.columns])
(df_train.set_index(df_train.columns.drop('artist_name',1).tolist()).artist_name.str.split('|', expand=True).stack().reset_index().rename(columns={0:'artist_name'}).loc[:, df_train.columns])
# Out:
#                                                msno  \
# 0      zRfOEH4Bl09lWEbWtYVEp5CffQ5VBDcSNFLumK291As=
# 1      FYdHbSh9d8bEuHHkTO0fhVMybVwZCJz9hdGK6RFnmag=
# 2      z9E+9+h+/UBSUD+pB/w7gvhe5L6e7VG8o5c/fIkfbCM=
# 3      /NH6bPENe6jOUheEl65TNbsL/vCw5N6Er+wZKg6Bg7M=
# 4      7Ufso2/kfKOQuMCZl1UMyYL2Xu9uZwseNCPeYbqbuHY=
# 5      JF+HD7AEy57Vc1NIrfe/on/mcnS2rBeRx6UVLua01Fw=
# 6      DwQLXL3Ts0a8+l9GRTBCqsBCbe95sln859meMhcrVIU=
# 7      nwDyh5Z5+UdqmoSoIt7EqLbob0PGHVxu5UVt/0mh01Q=
# 8      6Hd5xT+nOqkeiwc0i/qF6hhHGutBigH1Cx3x2L9hoTw=
# 9      9ijgLhtFIb0vwRnRCe91ZJmx4mZCLa9x9XN2GpLT0Co=
# 10     zO1Vlvhz7MkOpynI4K1nqiDhTZaodsBPpcBgMY95MO8=
# 11     EIcHSEbP4iIUGgQkT1uKn4r/1nTbJbj6SQMjhRDomI0=
# 12     32pL7qQu81kT4nqBP4kpPzDwmqVOmJ70NnWRZp6BZuw=
# 13     jP2MGGAr+2Cm7O8iUKyzH8FuVtPkhuHtpo5qXIO30yc=
# 14     0KZatRIW8dstwYu943eWJeNQWAcruU3tjjMxFCYnr2o=
# 15     gGNO/4lQdB22HiKZid8Dl08+bmiLqO7dg75pGfZ5PJU=
# 16     0P4ZpN1yl46bvR85dVQhCkRTnHLSVyrhfRb4LVp4Y1M=
# 17     92d/00pd/yshg2mGn58QXR16RZD+n+qs57wPUCfuodM=
# 18     7OLJOdmBMLeyq8zbMAsHSPRJddsgUA3VOPlB1kT9WR8=
# 19     UD3oYvR3Bn8KAQ0Dk8vLd6X0LaDpWiuEWY7wNM906C4=
# 20     4TYmGNbpCN71z0SbTQz8CQLHuicbVShzvmxA1kmFGG4=
# 21     W1K8rAPMoWMSaRYs/z/+uRpJ/EQyTYkqQjqNKNIX18A=
# 22     LjuMIC48XR0RbjYU3YsUXqSINC1oSnyBL6rabbL+yRs=
# 23     Mn98O4X/zceMt9nswcoq08F16ciCqhuN7lQ951MAL2o=
# 24     sVugkvbvu/dimeH5WXmQ+zKNMUv/ErC9E1VpUOQ5e9E=
# 25     4UMiRhVRNoKDCHvUHR4QlCcvreDD5smaqEydCE0vo0M=
# 26     pTQ05XKkbOllhCdrebcCaTsvY8ddPHG0Xb8NU/k4DKE=
# 27     uvBnRfN5BCoiSOzUB2GnjzNIgX4VE+UBVSuZ8wW58Eo=
# 28     3jNNXlg5Hej57lHE6Ht9dRgiISWwK74tpYRMjaSnmig=
# 29     O830o0lZIiJEWDuevQVH9aIj5jmucf2yl1hzI942sLo=
# ...                                             ...
# 28999  OOUnJuX4SteRhUdJZ9B2DqtfiwsfcZVBefEhXLeBsFg=
# 29000  2DnvslFy8Po3vODJcrIzdSFB4af1YoTbv31/M2znaGs=
# 29001  d0FlvocXRAyCXRhC9kxNw1AXGPXp+Lli1LrandTO4xM=
# 29002  RgygWvMTnp+M7tKJEHJo1w9sYgWwE+/hpXUA2NGj7v4=
# 29003  GpO5Rlr8kdcZfkxtgmXl8XKxk23x+5UINjirMj0aCZ8=
# 29004  doXNgtlSdG9CmBBm55s4HTQ7Oay6RpLBCbeIU1NPayo=
# 29005  la8sTdnrFG3nmOtFov/i/gMhCSVSCdiE8DGvnyDxIS0=
# 29006  92uxkth9BIx8yYfe+L4EmvBKtnGxkbPgArjQFDK61mY=
# 29007  NeRIsFaPQMQ72V3iZf5tv6M+WMvUH4gEmXid05oD1QA=
# 29008  klZwE6vfu35TvI8HbkezlFA+MFBoTpodEMvRYDi0Hz0=
# 29009  atrz/2Sb30O1abI6KicyvN+JlRpUMvNu5KhvddbDzqY=
# 29010  atrz/2Sb30O1abI6KicyvN+JlRpUMvNu5KhvddbDzqY=
# 29011  atrz/2Sb30O1abI6KicyvN+JlRpUMvNu5KhvddbDzqY=
# 29012  atrz/2Sb30O1abI6KicyvN+JlRpUMvNu5KhvddbDzqY=
# 29013  atrz/2Sb30O1abI6KicyvN+JlRpUMvNu5KhvddbDzqY=
# 29014  U4Q4hVqY/sPN251IBp+COoBOYKMz7XycauPP2vbnyYE=
# 29015  OOETiYOFhuTowtgRUIiKommGv0eo6XUHLc1ofgwcJew=
# 29016  RgygWvMTnp+M7tKJEHJo1w9sYgWwE+/hpXUA2NGj7v4=
# 29017  RgygWvMTnp+M7tKJEHJo1w9sYgWwE+/hpXUA2NGj7v4=
# 29018  Wur/Yk0Xa62eIFUs7HD5Wx6ELw3yjyhUsDb+utQBDuU=
# 29019  Wur/Yk0Xa62eIFUs7HD5Wx6ELw3yjyhUsDb+utQBDuU=
# 29020  0mCqItE5X4/AAknz/KHx8aMetKSueqHY8htLEp8X+Ok=
# 29021  TViWhi9eR/PSpcaLiJA6eBTHTeumGIJcsH6h3axme0M=
# 29022  mJFueE2CnrvbqLa9/XaBcu7ZATY1gELuyCx+WSy/KB4=
# 29023  X5UVXzOlTLAjH5RJcmSrejq4K0jTQ95Crc3cSbqwWUA=
# 29024  X5UVXzOlTLAjH5RJcmSrejq4K0jTQ95Crc3cSbqwWUA=
# 29025  X5UVXzOlTLAjH5RJcmSrejq4K0jTQ95Crc3cSbqwWUA=
# 29026  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=
# 29027  WcpqlCd/V0fFVNo7NkxhU/ezGPVzHKCC127KzqZx4Yw=
# 29028  e+JFzA/xsWmR6LNEHpDN2iC1aYqvBqBPFStYbddxDlw=
#
#                                             song_id source_system_tab  \
# 0      ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=        my library
# 1      ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=        my library
# 2      ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=        my library
# 3      ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=        my library
# 4      ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=        my library
# 5      ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=        my library
# 6      ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=        my library
# 7      ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=        my library
# 8      ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=        my library
# 9      ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=        my library
# 10     ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=        my library
# 11     ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=            search
# 12     ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=            search
# 13     ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=        my library
# 14     ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=        my library
# 15     ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=        my library
# 16     ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=        my library
# 17     ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=            search
# 18     ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=        my library
# 19     ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=        my library
# 20     ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=        my library
# 21     ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=        my library
# 22     ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=        my library
# 23     ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=        my library
# 24     ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=        my library
# 25     ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=            search
# 26     ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=        my library
# 27     ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=        my library
# 28     ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=            search
# 29     ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=        my library
# ...                                             ...               ...
# 28999  YUnnstkxKj1T9YeDX+gLUPUH0hPY/wVXmJwg3jAGYEU=             radio
# 29000  vJU8QYOa5h1m99e0Ey4Q9ow6eXK753b6ukVU5LVEOx4=        my library
# 29001  07BdK52M9xmlqgzKI92bkWUlKtUx3qlWKHfhI2eXkMU=        my library
# 29002  uXZuu6k3aWAxNL0dW8NIe7D1dBb624TFw4P0WhlBofU=          discover
# 29003  oFqJWjDgpNnl/nXNDwM0iYwvFPHUCJL3SyTeSyIjGjQ=            search
# 29004  vvJVDPlBOWHot12c0/pBsxWd6ENJGzoBFz4QZXyApa0=        my library
# 29005  LcFfFp97SMUlZD+t7uz2OmkZrSCrDFfjALuUxplSRWc=        my library
# 29006  oTnCSAPxetkhF0pwIwCl3KaWwP2HWjZumpVqljC0IzQ=             radio
# 29007  fodekob0KkOBbS547gyo7wsQBkmHhI7DIkPXt/4QgMA=        my library
# 29008  7C9DlFl6jBI67Dm+i/n/6Di5/dhyHyImF0ZWCTq3D+g=            search
# 29009  MXs8D81XzgpclAXQDtW0eCa3ChnUd1KSKH+xOAKR2cw=            search
# 29010  bh1Udk4BvrI9j5syrAags+DfWJZReQBm+6GPCVblsuQ=            search
# 29011  dNJV7w0LQsflGYfUTB/TOYxwsSeSBYfO9+h+8Q9oNmQ=            search
# 29012  Y5i+epwOnMXCAns9h3Onl+XXxN9Ziph3/oPzweU+Crc=            search
# 29013  38QeeVRnDHdYnczZ1V2aVLRKAOjDA0goBZ67ez/aWJk=            search
# 29014  2wDbjyYKAyk5IOIa9srhCdwWf8wHxHT7SgSFS+xuzho=             radio
# 29015  Fpx1mjNsLqm4ks3zW0tAHOKHiMvn1jdsfqSYKieEjV8=          discover
# 29016  OnYyTD3f1Rih/ydk2OjKW7TXYxGbuzCduGPspFHBwYA=       listen with
# 29017  tOKtarLUiKwULqUpsko+KmqHIWsKwvKUqxEdmuIf/FA=          discover
# 29018  JO3mA1f8Om+uBGVs6p9TwaArN73EPu2Wgn5C0q/i1Iw=        my library
# 29019  f3aVlAzyEvr16qxZHhUQPMedXJzh6p5ypwSX/2QxyWA=        my library
# 29020  +ADAIXC8NOuwacPx1AWRVsKeTF6P7feL2F6skYxqkOU=        my library
# 29021  YRl9VMfk81oIFIsBdG4+YdJJIXMD3bD8rMvuqS6PsWo=        my library
# 29022  YFBhvzFxempWQwirrtPo3uaqGTaCOpS4Hw+3yS+bpoY=        my library
# 29023  hNvwMc/X017Q0+VDyZnxJFepW1bUyaDhPJ7I+qVltXM=            search
# 29024  fFPJJJ7xKv+kB74XaZu4Suxs70XcBYfJOq6cyAxKTOg=            search
# 29025  CWsPkIZtpQ3Z01UYbk9OulKveCGKeysOr/U6GMTDTxA=            search
# 29026  FQiDhxfuX3uvrFIdza7kdzo9c+GJuO8JwWOaILovGMM=           explore
# 29027  oJOTIQri5NYcDD7AnAtPQ/B80bHNH9grxs4jmxNHnEg=           explore
# 29028  bvUuQEzyDmsdfBJ0KtBj3QTVBfa+TqKORadivlLaZ80=             radio
#
#         source_screen_name          source_type  target  song_length  \
# 0      Local playlist more       local-playlist       1       192679
# 1      Local playlist more       local-playlist       1       192679
# 2      Local playlist more       local-playlist       1       192679
# 3      Local playlist more       local-playlist       1       192679
# 4               Album more                album       1       192679
# 5      Local playlist more        local-library       1       192679
# 6      Local playlist more        local-library       1       192679
# 7      Local playlist more        local-library       1       192679
# 8      Local playlist more        local-library       1       192679
# 9      Local playlist more        local-library       1       192679
# 10     Local playlist more        local-library       1       192679
# 11              Album more                album       0       192679
# 12              Album more                album       1       192679
# 13              Album more                album       1       192679
# 14     Local playlist more       local-playlist       1       192679
# 15     Local playlist more        local-library       1       192679
# 16              My library       local-playlist       1       192679
# 17              Album more                album       1       192679
# 18              Album more                album       0       192679
# 19     Local playlist more       local-playlist       1       192679
# 20     Local playlist more        local-library       1       192679
# 21     Local playlist more       local-playlist       1       192679
# 22     Local playlist more       local-playlist       1       192679
# 23     Local playlist more       local-playlist       1       192679
# 24     Local playlist more        local-library       1       192679
# 25                  Search                 song       1       192679
# 26              Album more                album       1       192679
# 27     Local playlist more       local-playlist       0       192679
# 28              Album more                album       1       192679
# 29     Local playlist more       local-playlist       1       192679
# ...                    ...                  ...     ...          ...
# 28999                Radio                radio       0       139200
# 29000  Local playlist more       local-playlist       0       310543
# 29001               Search                 song       0       237087
# 29002                Radio                radio       0       150888
# 29003           Album more                album       1       301896
# 29004  Local playlist more        local-library       0       191276
# 29005           Album more                album       1       195000
# 29006                Radio                radio       0       298893
# 29007  Local playlist more        local-library       1       234010
# 29008           Album more                album       0       211382
# 29009           Album more                album       0       165407
# 29010               Search                 song       0       144823
# 29011           Album more                album       0       194456
# 29012           Album more                album       0       219011
# 29013           Album more                album       0       202292
# 29014                Radio                radio       0       116688
# 29015     Discover Feature  song-based-playlist       0       256104
# 29016                Radio                radio       0       190328
# 29017                Radio                radio       0       463841
# 29018  Local playlist more       local-playlist       1       201230
# 29019  Local playlist more       local-playlist       1       288374
# 29020  Local playlist more       local-playlist       0       284107
# 29021  Local playlist more       local-playlist       1       176901
# 29022               Search      online-playlist       1       274599
# 29023           Album more                album       0       201015
# 29024           Album more                album       0       358005
# 29025           Album more                album       0       263941
# 29026              Explore      online-playlist       0       405943
# 29027              Explore      online-playlist       0       259448
# 29028                Radio                radio       0       303943
#
#              genre_ids                  artist_name  \
# 0              242|726                       寶寶水晶音樂
# 1              242|726                       寶寶水晶音樂
# 2              242|726                       寶寶水晶音樂
# 3              242|726                       寶寶水晶音樂
# 4              242|726                       寶寶水晶音樂
# 5              242|726                       寶寶水晶音樂
# 6              242|726                       寶寶水晶音樂
# 7              242|726                       寶寶水晶音樂
# 8              242|726                       寶寶水晶音樂
# 9              242|726                       寶寶水晶音樂
# 10             242|726                       寶寶水晶音樂
# 11             242|726                       寶寶水晶音樂
# 12             242|726                       寶寶水晶音樂
# 13             242|726                       寶寶水晶音樂
# 14             242|726                       寶寶水晶音樂
# 15             242|726                       寶寶水晶音樂
# 16             242|726                       寶寶水晶音樂
# 17             242|726                       寶寶水晶音樂
# 18             242|726                       寶寶水晶音樂
# 19             242|726                       寶寶水晶音樂
# 20             242|726                       寶寶水晶音樂
# 21             242|726                       寶寶水晶音樂
# 22             242|726                       寶寶水晶音樂
# 23             242|726                       寶寶水晶音樂
# 24             242|726                       寶寶水晶音樂
# 25             242|726                       寶寶水晶音樂
# 26             242|726                       寶寶水晶音樂
# 27             242|726                       寶寶水晶音樂
# 28             242|726                       寶寶水晶音樂
# 29             242|726                       寶寶水晶音樂
# ...                ...                          ...
# 28999          786|947           証聲音樂圖書館 ECHO MUSIC
# 29000              242           CHALAW & PASSIWALI
# 29001  864|857|850|843               ANISON PROJECT
# 29002              786                         巴薩諾瓦
# 29003             1152                  阿努．卡力亭．沙力朋安
# 29004             1609                       Wa$$up
# 29005              786                         貴族精選
# 29006             1011            คาราบาว (Carabao)
# 29007              786                         貴族精選
# 29008             1609                     DJ Elvis
# 29009              958                     Martynas
# 29010              958                     Martynas
# 29011              958                     Martynas
# 29012              958                     Martynas
# 29013              958                     Martynas
# 29014              786                         巴薩諾瓦
# 29015              458                    第一次 電影原聲帶
# 29016             2022                      Chicago
# 29017             2122  Preservation Hall Jazz Band
# 29018              465                     JAMBINAI
# 29019              465                     JAMBINAI
# 29020              465                  Alicia Keys
# 29021              242                   零感音樂製作有限公司
# 29022             2194                          劉秀暐
# 29023              873                 香光快樂行 佛曲合唱專輯
# 29024              873                 香光快樂行 佛曲合唱專輯
# 29025              873                 香光快樂行 佛曲合唱專輯
# 29026             1609                    Ludistelo
# 29027             1609                    Ludistelo
# 29028             2022                  Rasmus Nøhr
#
#                                                 composer  \
# 0                                      Alan Irwin Menken
# 1                                      Alan Irwin Menken
# 2                                      Alan Irwin Menken
# 3                                      Alan Irwin Menken
# 4                                      Alan Irwin Menken
# 5                                      Alan Irwin Menken
# 6                                      Alan Irwin Menken
# 7                                      Alan Irwin Menken
# 8                                      Alan Irwin Menken
# 9                                      Alan Irwin Menken
# 10                                     Alan Irwin Menken
# 11                                     Alan Irwin Menken
# 12                                     Alan Irwin Menken
# 13                                     Alan Irwin Menken
# 14                                     Alan Irwin Menken
# 15                                     Alan Irwin Menken
# 16                                     Alan Irwin Menken
# 17                                     Alan Irwin Menken
# 18                                     Alan Irwin Menken
# 19                                     Alan Irwin Menken
# 20                                     Alan Irwin Menken
# 21                                     Alan Irwin Menken
# 22                                     Alan Irwin Menken
# 23                                     Alan Irwin Menken
# 24                                     Alan Irwin Menken
# 25                                     Alan Irwin Menken
# 26                                     Alan Irwin Menken
# 27                                     Alan Irwin Menken
# 28                                     Alan Irwin Menken
# 29                                     Alan Irwin Menken
# ...                                                  ...
# 28999                                    Cameron McBride
# 29000                                                 查勞
# 29001                                             ＰＲＡＧＵＥ
# 29002                                    SAULO FERNANDEZ
# 29003                                              阿努Anu
# 29004                                 Red Roc|Goldbanger
# 29005                                                劉家昌
# 29006                                            Carabao
# 29007                                                黃邦明
# 29008                     Oliver Heller、Milan Michalides
# 29009                                    Johannes Brahms
# 29010                                        Jean Lenoir
# 29011  Beyoncé Knowles| LaShawn Daniels| Rodney Jerki...
# 29012                                     Giuseppe Verdi
# 29013             Georges Bizet| Gerardo Matos Rodriguez
# 29014                    DANIEL CARL HOLTER / MATT SMITH
# 29015                                                周杰倫
# 29016                                         Terry Kath
# 29017  D. James LaRocca| Edwin Edwards| Henry W. Raga...
# 29018                                           JAMBINAI
# 29019                                           JAMBINAI
# 29020                   Alicia Keys| Kerry Brothers| Jr.
# 29021                                         零感音樂製作有限公司
# 29022                                                蔡孟甫
# 29023                                                 毅民
# 29024                                                 夢梅
# 29025                                                吳居徹
# 29026                                          Ludistelo
# 29027                                          Ludistelo
# 29028                                        Rasmus Nøhr
#
#                                                 lyricist  language
# 0                              Stephen Laurence Schwartz      -1.0
# 1                              Stephen Laurence Schwartz      -1.0
# 2                              Stephen Laurence Schwartz      -1.0
# 3                              Stephen Laurence Schwartz      -1.0
# 4                              Stephen Laurence Schwartz      -1.0
# 5                              Stephen Laurence Schwartz      -1.0
# 6                              Stephen Laurence Schwartz      -1.0
# 7                              Stephen Laurence Schwartz      -1.0
# 8                              Stephen Laurence Schwartz      -1.0
# 9                              Stephen Laurence Schwartz      -1.0
# 10                             Stephen Laurence Schwartz      -1.0
# 11                             Stephen Laurence Schwartz      -1.0
# 12                             Stephen Laurence Schwartz      -1.0
# 13                             Stephen Laurence Schwartz      -1.0
# 14                             Stephen Laurence Schwartz      -1.0
# 15                             Stephen Laurence Schwartz      -1.0
# 16                             Stephen Laurence Schwartz      -1.0
# 17                             Stephen Laurence Schwartz      -1.0
# 18                             Stephen Laurence Schwartz      -1.0
# 19                             Stephen Laurence Schwartz      -1.0
# 20                             Stephen Laurence Schwartz      -1.0
# 21                             Stephen Laurence Schwartz      -1.0
# 22                             Stephen Laurence Schwartz      -1.0
# 23                             Stephen Laurence Schwartz      -1.0
# 24                             Stephen Laurence Schwartz      -1.0
# 25                             Stephen Laurence Schwartz      -1.0
# 26                             Stephen Laurence Schwartz      -1.0
# 27                             Stephen Laurence Schwartz      -1.0
# 28                             Stephen Laurence Schwartz      -1.0
# 29                             Stephen Laurence Schwartz      -1.0
# ...                                                  ...       ...
# 28999                                    Cameron McBride      -1.0
# 29000                                                 查勞      -1.0
# 29001                                              鈴木　雄太      -1.0
# 29002                                    SAULO FERNANDEZ      -1.0
# 29003                                              阿努Anu      -1.0
# 29004                                            Red Roc      -1.0
# 29005                                                 瓊瑤      -1.0
# 29006                           Carabao| Yuenyong Opakul      -1.0
# 29007                                                黃邦明      -1.0
# 29008                     Oliver Heller、Milan Michalides      -1.0
# 29009                                    Johannes Brahms      -1.0
# 29010                                        Jean Lenoir      -1.0
# 29011  Beyoncé Knowles| LaShawn Daniels| Rodney Jerki...      -1.0
# 29012                                     Giuseppe Verdi      -1.0
# 29013             Georges Bizet| Gerardo Matos Rodriguez      -1.0
# 29014                    DANIEL CARL HOLTER / MATT SMITH      -1.0
# 29015                                                方文山      -1.0
# 29016                                         Terry Kath      -1.0
# 29017                                     Harry Da Costa      -1.0
# 29018                                          Kim Bo Mi      -1.0
# 29019                                         Lee Il Woo      -1.0
# 29020                   Alicia Keys| Kerry Brothers| Jr.      -1.0
# 29021                                         零感音樂製作有限公司      -1.0
# 29022                                                蔡孟甫      -1.0
# 29023                                                 經文      -1.0
# 29024                                               心然法師      -1.0
# 29025                                                普力宏      -1.0
# 29026                                          Ludistelo      -1.0
# 29027                                          Ludistelo      -1.0
# 29028                                        Rasmus Nøhr      -1.0
#
# [29029 rows x 12 columns]

# %%
df_train = df_train.drop('source_system_tab', 1)
df_train = df_train.drop('source_screen_name', 1)
df_train = df_train.drop('source_type', 1)
df_train = df_train.drop('song_length', 1)
df_train.head(5)
# Out:
#                                                  msno  \
# 1248882  zRfOEH4Bl09lWEbWtYVEp5CffQ5VBDcSNFLumK291As=
# 1248883  FYdHbSh9d8bEuHHkTO0fhVMybVwZCJz9hdGK6RFnmag=
# 1248884  z9E+9+h+/UBSUD+pB/w7gvhe5L6e7VG8o5c/fIkfbCM=
# 1248885  /NH6bPENe6jOUheEl65TNbsL/vCw5N6Er+wZKg6Bg7M=
# 1248886  7Ufso2/kfKOQuMCZl1UMyYL2Xu9uZwseNCPeYbqbuHY=
#
#                                               song_id  target genre_ids  \
# 1248882  ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=       1   242|726
# 1248883  ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=       1   242|726
# 1248884  ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=       1   242|726
# 1248885  ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=       1   242|726
# 1248886  ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=       1   242|726
#
#         artist_name           composer                   lyricist  language
# 1248882      寶寶水晶音樂  Alan Irwin Menken  Stephen Laurence Schwartz      -1.0
# 1248883      寶寶水晶音樂  Alan Irwin Menken  Stephen Laurence Schwartz      -1.0
# 1248884      寶寶水晶音樂  Alan Irwin Menken  Stephen Laurence Schwartz      -1.0
# 1248885      寶寶水晶音樂  Alan Irwin Menken  Stephen Laurence Schwartz      -1.0
# 1248886      寶寶水晶音樂  Alan Irwin Menken  Stephen Laurence Schwartz      -1.0

# %%
from sklearn import preprocessing
# Create a label (category) encoder object
le = preprocessing.LabelEncoder()

# Fit the encoder to the pandas column
le.fit(df_train['msno'])

# Apply the fitted encoder to the pandas column
df_train['msno_num'] = le.transform(df_train['msno'])

# %%
# Fit the encoder to the pandas column
le.fit(df_train['genre_ids'])

# Apply the fitted encoder to the pandas column
df_train['genre_ids_num'] = le.transform(df_train['genre_ids'])

# %%
# Fit the encoder to the pandas column
le.fit(df_train['lyricist'])

# Apply the fitted encoder to the pandas column
df_train['lyricist_num'] = le.transform(df_train['lyricist'])

# %%
# Fit the encoder to the pandas column
le.fit(df_train['composer'])

# Apply the fitted encoder to the pandas column
df_train['composer_num'] = le.transform(df_train['composer'])

# %%
# Fit the encoder to the pandas column
le.fit(df_train['artist_name'])

# Apply the fitted encoder to the pandas column
df_train['artist_name_num'] = le.transform(df_train['artist_name'])

# %%
df_train.head()
# Out:
#                                                  msno  \
# 1248882  zRfOEH4Bl09lWEbWtYVEp5CffQ5VBDcSNFLumK291As=
# 1248883  FYdHbSh9d8bEuHHkTO0fhVMybVwZCJz9hdGK6RFnmag=
# 1248884  z9E+9+h+/UBSUD+pB/w7gvhe5L6e7VG8o5c/fIkfbCM=
# 1248885  /NH6bPENe6jOUheEl65TNbsL/vCw5N6Er+wZKg6Bg7M=
# 1248886  7Ufso2/kfKOQuMCZl1UMyYL2Xu9uZwseNCPeYbqbuHY=
#
#                                               song_id  target genre_ids  \
# 1248882  ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=       1   242|726
# 1248883  ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=       1   242|726
# 1248884  ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=       1   242|726
# 1248885  ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=       1   242|726
# 1248886  ilNsh4b995pdJD3LVYCQB6JdWAM7AH/w4QnvbxWR2XE=       1   242|726
#
#         artist_name           composer                   lyricist  language  \
# 1248882      寶寶水晶音樂  Alan Irwin Menken  Stephen Laurence Schwartz      -1.0
# 1248883      寶寶水晶音樂  Alan Irwin Menken  Stephen Laurence Schwartz      -1.0
# 1248884      寶寶水晶音樂  Alan Irwin Menken  Stephen Laurence Schwartz      -1.0
# 1248885      寶寶水晶音樂  Alan Irwin Menken  Stephen Laurence Schwartz      -1.0
# 1248886      寶寶水晶音樂  Alan Irwin Menken  Stephen Laurence Schwartz      -1.0
#
#          msno_num  genre_ids_num  lyricist_num  composer_num  artist_name_num
# 1248882      7406             56          1712            67              745
# 1248883      2021             56          1712            67              745
# 1248884      7372             56          1712            67              745
# 1248885       147             56          1712            67              745
# 1248886      1104             56          1712            67              745

# %%
#translation of languages to english

from googletrans import Translator
translator = Translator()

for i in range(0, len(df_train)):
    df_songs.composer.iloc[i] = translator.translate(df_songs.composer.iloc[i])
    print(i)

# %%
print(df_songs.composer[670:1000])

# %%
df_songs['composer'] = df_songs['composer'].astype('str')

# %%
s = df_songs.composer[0]
start = s.find('text=') +5
end = s.find(',', start)
s[start:end]

# %%
for i in range(680, 1000):
    start = df_songs.composer[i].find('text=') +5
    end = df_songs.composer[i].find(',', start)
    df_songs.composer[i] = df_songs.composer[i][start:end]

# %%
x = df_train[['lyricist_num','composer_num','artist_name_num','genre_ids_num']].copy()
# x = df_train[['composer_num','artist_name_num','genre_ids_num']].copy()
x.head(8)
# Out:
#          lyricist_num  composer_num  artist_name_num  genre_ids_num
# 1248882          1712            67              745             56
# 1248883          1712            67              745             56
# 1248884          1712            67              745             56
# 1248885          1712            67              745             56
# 1248886          1712            67              745             56
# 1248887          1712            67              745             56
# 1248888          1712            67              745             56
# 1248889          1712            67              745             56

# %%
y = df_train[['target']].copy()
y.head()
# Out:
#          target
# 1248882       1
# 1248883       1
# 1248884       1
# 1248885       1
# 1248886       1

# %%
# create a base classifier used to evaluate a subset of attributes
model = LogisticRegression()

# create the RFE model and select 3 attributes
rfe = RFE(model, 3)
rfe = rfe.fit(x, y.values.ravel())

# summarize the selection of the attributes
print(rfe.support_)
print(rfe.ranking_)
# Out:
# [False  True  True  True]
# [2 1 1 1]

# %%
#split train test data

from sklearn.model_selection import train_test_split

trainx, testx = train_test_split(x, test_size=0.2)
trainy, testy = train_test_split(y, test_size=0.2)

# %%
# try1 SVM 
from sklearn import svm
clf = svm.LinearSVC()
clf.fit(trainx , trainy.values.ravel())
pred = clf.predict(testx)
print(pred)
# Out:
# [1 1 1 ..., 0 0 1]

# %%
#accuracy calculation SVM
from sklearn.metrics import accuracy_score
acc = accuracy_score(testy, pred)
print(acc)
# Out:
# 0.496176572819

# %%
# Try2 logistic regression

from sklearn import linear_model
h = .02  # step size in the mesh
logreg = linear_model.LogisticRegression(C=1e5)
# we create an instance of Neighbours Classifier and fit the data.
logreg.fit(trainx, trainy.values.ravel())
pred = logreg.predict(testx)

# %%
#accuracy calculation
from sklearn.metrics import accuracy_score
acc = accuracy_score(testy, pred)
print(acc)
# Out:
# 0.554570733403

# %%
#try3 GradientBoostingClassifier

from sklearn.ensemble import GradientBoostingClassifier
clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,
max_depth=1, random_state=0).fit(trainx, trainy.values.ravel())

# %%
pred = clf.predict(testx)
print(pred)
# Out:
# [0 0 0 ..., 0 0 0]

# %%
#accuracy calculation logistic Regression
from sklearn.metrics import accuracy_score
acc = accuracy_score(testy, pred)
print(acc)
# Out:
# 0.555787278415
